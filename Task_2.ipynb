# %%
Task 2
 
 # How i work best in programming 
 ### Preferred environment

 I work best in a *quiet and organized environment  where i can fully conccentrate on problem solving skills. I prefer using **Vs COde** or other **IDLE** because they are simple and efficient.

 ### MY PREFERENCES
 
 - a quiet and organized environment
 - a place fully equipped device ie with proper *idle* and *good internet connections*
 - a good teammate.
